# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.4 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# %%writefile plate.yaml
# path: /kaggle/input/datasets/hoangvudinh0301/vn-plate-dataset/vn_license_plate
#
# train: images/train
# val: images/val
#
# nc: 1
# names: ['plate']
# Out:
# Writing plate.yaml

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

results = model.train(data="plate.yaml", 
                      epochs=100, 
                      imgsz=960, 
                      degrees=10,
                      scale=0.5,
                      fliplr=0.5,
                      batch=16)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.30 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
